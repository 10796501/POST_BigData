# %%
# !pip install geocoder

# %%
import geocoder
import pandas as pd
import csv

# %%
df = pd.read_csv('Post_All_new.csv', encoding = "big5")

# %%
df
# Out:
#        郵遞區號      電腦局號    郵務局號       局名    電腦局名   縣市 鄉鎮市區  \
# 0     10044  000100-6  100000   臺北北門郵局  臺北901支  臺北市  中正區
# 1     10064  000101-0  100001   臺北東門郵局    臺北1支  臺北市  中正區
# 2     10846  000102-3  100002  臺北漢中街郵局    臺北2支  臺北市  萬華區
# 3     10847  000103-7  100003   臺北西園郵局    臺北3支  臺北市  萬華區
# 4     10851  000104-1  100004   臺北龍山郵局    臺北4支  臺北市  萬華區
# 5     10075  000105-4  100005   臺北南海郵局    臺北5支  臺北市  中正區
# 6     10083  000106-8  100006   臺北螢橋郵局    臺北6支  臺北市  中正區
# 7     10644  000107-1  100007   臺北青田郵局    臺北7支  臺北市  大安區
# 8     10041  000108-5  100008  臺北復興橋郵局    臺北8支  臺北市  中正區
# 9     10444  000109-9  100009   臺北中山郵局    臺北9支  臺北市  中山區
# 10    10343  000110-1  100010  臺北迪化街郵局   臺北10支  臺北市  大同區
# 11    10356  000111-4  100011   臺北圓環郵局   臺北11支  臺北市  大同區
# 12    10051  000112-8  100012    行政院郵局   臺北12支  臺北市  中正區
# 13    10091  000113-1  100013   臺北公館郵局   臺北13支  臺北市  中正區
# 14    10048  000114-5  100014    國史館郵局   臺北14支  臺北市  中正區
# ...

# %%
for i in range(0,1299):
    g = geocoder.arcgis(u"%s"% df['完整地址'][i])
    g.latlng
